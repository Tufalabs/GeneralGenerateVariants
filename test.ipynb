# %%
from generate_variants import process_prompt

# %%
question = "Generate variants of cats"

test = await process_prompt(question, ["easier", "harder"], 10, 0)

test
# Out:
# /Users/tamassimonds/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 question = "Generate variants of cats"
# ----> 3 test = await process_prompt(question, ["easier", "harder"], 10, 0)
#       5 test
#
# File ~/Documents/Code/Ai/GeneralGenerateVariants/generate_variants.py:167, in process_prompt(base_prompt, difficulties, num_variants, recursion_depth)
#     164         count = 10 if (i < num_chunks - 1) else (total_to_request - 10 * (num_chunks - 1))
#     165         tasks.append((difficulty, generate_variant_chunk(base_prompt, difficulty, count)))
# ...
